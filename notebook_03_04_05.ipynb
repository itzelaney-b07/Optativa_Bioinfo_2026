# %% [markdown]
# # 🐍 Notebook 3: Introducción a las Listas
# **Basado en Python Crash Course, 3ra Edición — Capítulo 3**
#
# ---
#
# ## 🎯 Objetivos de aprendizaje
# - Crear y acceder a listas
# - Modificar, agregar y eliminar elementos
# - Organizar listas con sort y reverse
# - Evitar errores de índice
#
# > 💡 **Para quien ya programa:** Las listas de Python son similares a los arrays dinámicos (ArrayList en Java, vector en C++). Se redimensionan automáticamente, pueden mezclar tipos y tienen muchos métodos útiles incorporados.
#
# ---

# %% [markdown]
# ## 3.1 Creación y Acceso a Listas

# %%
# Una lista es una colección ordenada y mutable
# Se define con corchetes []
lenguajes = ['Python', 'Java', 'C++', 'JavaScript', 'Go']
print(lenguajes)
print(type(lenguajes))

# Las listas pueden mezclar tipos (aunque no es recomendable)
mezcla = [42, "hola", 3.14, True, None]
print(mezcla)

# %%
# Acceso por índice — empieza en 0 (como en la mayoría de lenguajes)
frutas = ['manzana', 'banana', 'cereza', 'durazno', 'fresa']

print(frutas[0])   # Primera: manzana
print(frutas[2])   # Tercera: cereza
print(frutas[-1])  # Última: fresa (índice negativo!)
print(frutas[-2])  # Penúltima: durazno

# Slicing — obtener sublistas [inicio:fin:paso]
print(frutas[1:3])   # ['banana', 'cereza'] — índice 1 y 2 (no incluye 3)
print(frutas[:3])    # Primeros 3 elementos
print(frutas[2:])    # Desde índice 2 hasta el final
print(frutas[::2])   # Cada 2 elementos
print(frutas[::-1])  # Lista al revés!

# %% [markdown]
# ## 3.2 Modificar Listas

# %%
# Las listas son MUTABLES — puedes cambiarlas después de crearlas
# (A diferencia de los strings que son inmutables)

colores = ['rojo', 'verde', 'azul']
print(f"Original: {colores}")

# Modificar elemento existente
colores[1] = 'amarillo'
print(f"Modificado: {colores}")

# Agregar al final
colores.append('morado')
print(f"Con append: {colores}")

# Insertar en posición específica
colores.insert(1, 'naranja')
print(f"Con insert: {colores}")
# Out:
# Original: ['rojo', 'verde', 'azul']
# Modificado: ['rojo', 'amarillo', 'azul']
# Con append: ['rojo', 'amarillo', 'azul', 'morado']
# Con insert: ['rojo', 'naranja', 'amarillo', 'azul', 'morado']

# %%
# Eliminar elementos
numeros = [1, 2, 3, 4, 5, 3, 6]

# del — elimina por índice
del numeros[0]
print(f"Después de del: {numeros}")

# .remove() — elimina la primera ocurrencia de un valor
numeros.remove(3)
print(f"Después de remove(3): {numeros}")

# .pop() — elimina y retorna el último elemento (o el de índice dado)
ultimo = numeros.pop()
print(f"Elemento eliminado: {ultimo}")
print(f"Lista restante: {numeros}")

segundo = numeros.pop(1)
print(f"Elemento en índice 1 eliminado: {segundo}")
print(f"Lista final: {numeros}")
# Out:
# Después de del: [2, 3, 4, 5, 3, 6]
# Después de remove(3): [2, 4, 5, 3, 6]
# Elemento eliminado: 6
# Lista restante: [2, 4, 5, 3]
# Elemento en índice 1 eliminado: 4
# Lista final: [2, 5, 3]

# %% [markdown]
# ## 3.3 Organizar Listas

# %%
# .sort() — ordena la lista EN SITIO (modifica la original)
autos = ['bmw', 'audi', 'toyota', 'ford', 'honda']
print(f"Original: {autos}")

autos.sort()
print(f"Ordenado A-Z: {autos}")

autos.sort(reverse=True)
print(f"Ordenado Z-A: {autos}")

# sorted() — retorna NUEVA lista ordenada (no modifica la original)
frutas = ['cereza', 'manzana', 'banana']
frutas_ordenadas = sorted(frutas)
print(f"Frutas original: {frutas}")
print(f"Frutas ordenadas: {frutas_ordenadas}")
# Out:
# Original: ['bmw', 'audi', 'toyota', 'ford', 'honda']
# Ordenado A-Z: ['audi', 'bmw', 'ford', 'honda', 'toyota']
# Ordenado Z-A: ['toyota', 'honda', 'ford', 'bmw', 'audi']
# Frutas original: ['cereza', 'manzana', 'banana']
# Frutas ordenadas: ['banana', 'cereza', 'manzana']

# %%
# Información sobre la lista
numeros = [3, 1, 4, 1, 5, 9, 2, 6, 5, 3, 5]

print(f"Lista: {numeros}")
print(f"Longitud: {len(numeros)}")
print(f"Mínimo: {min(numeros)}")
print(f"Máximo: {max(numeros)}")
print(f"Suma: {sum(numeros)}")
print(f"¿Está el 9? {9 in numeros}")
print(f"¿Cuántos 5 hay? {numeros.count(5)}")
print(f"Índice del 9: {numeros.index(9)}")

# %% [markdown]
# ---
# ## ✏️ Ejercicios Prácticos
#
# ### Ejercicio 3.1: Lista de Invitados

# %%
# Ejercicio 3.1
# Tienes una lista de invitados a una cena
invitados = ['María', 'Carlos', 'Ana', 'Pedro']

# 1. Muestra un mensaje personalizado para cada invitado
for invitado in invitados:
    print(f"Estimado/a {invitado}, te invitamos a nuestra cena especial.")

# 2. Pedro no puede venir, reemplázalo por Laura
invitados[invitados.index('Pedro')] = 'Laura'
print(f"Lista actualizada: {invitados}")

# 3. Conseguiste una mesa más grande, agrega 2 personas más
invitados.append('Roberto')
invitados.insert(0, 'Elena')
print(f"Lista final: {invitados}")
print(f"Total de invitados: {len(invitados)}")
# Out:
# Estimado/a María, te invitamos a nuestra cena especial.
# Estimado/a Carlos, te invitamos a nuestra cena especial.
# Estimado/a Ana, te invitamos a nuestra cena especial.
# Estimado/a Pedro, te invitamos a nuestra cena especial.
# Lista actualizada: ['María', 'Carlos', 'Ana', 'Laura']
# Lista final: ['Elena', 'María', 'Carlos', 'Ana', 'Laura', 'Roberto']
# Total de invitados: 6

# %%
# Ejercicio 3.1
# Tienes una lista de invitados a una cena
personas = ['María', 'Carlos', 'Ana', 'Pedro']

# 1. Muestra un mensaje personalizado para cada invitado
for persona in personas:
    print(f"Estimado/a {persona}, te invitamos a nuestra cena especial.")
# Out:
# Estimado/a María, te invitamos a nuestra cena especial.
# Estimado/a Carlos, te invitamos a nuestra cena especial.
# Estimado/a Ana, te invitamos a nuestra cena especial.
# Estimado/a Pedro, te invitamos a nuestra cena especial.

# %% [markdown]
# ### Ejercicio 3.2: Gestión de Lista de Tareas

# %%
# Ejercicio 3.2 — Sistema de tareas simple
tareas = ['Revisar email', 'Escribir reporte', 'Reunión 3pm',
          'Almorzar', 'Revisar código']

print("=== LISTA DE TAREAS ===")
for i, tarea in enumerate(tareas, 1):
    print(f"{i}. {tarea}")

# Ordenar alfabéticamente
tareas_ordenadas = sorted(tareas)
print("
=== TAREAS ORDENADAS ===")
for i, tarea in enumerate(tareas_ordenadas, 1):
    print(f"{i}. {tarea}")

# Completar primera tarea
completada = tareas.pop(0)
print(f"
✅ Tarea completada: {completada}")
print(f"Tareas restantes: {len(tareas)}")

# %% [markdown]
# ---
# ## 🚀 Mini Proyecto: Administrador de Lista de Compras

# %%
# MINI PROYECTO: Lista de Compras
lista_compras = []

# Agregar productos
productos_iniciales = [
    ('Leche', 2),
    ('Pan', 1),
    ('Huevos', 12),
    ('Manzanas', 6),
    ('Yogur', 4)
]

# Construir la lista
for producto, cantidad in productos_iniciales:
    lista_compras.append(f"{cantidad}x {producto}")

print("=== LISTA DE COMPRAS ===")
for item in sorted(lista_compras):
    print(f"  ☐ {item}")

# Simulamos que ya compramos algunos artículos
comprados = ['2x Leche', '1x Pan']
pendientes = [item for item in lista_compras if item not in comprados]

print(f"
=== PENDIENTES ({len(pendientes)}) ===")
for item in pendientes:
    print(f"  ☐ {item}")

print(f"
=== COMPRADOS ({len(comprados)}) ===")
for item in comprados:
    print(f"  ✅ {item}")

# %% [markdown]
# ---
# ## 🏆 Desafíos (sin solución)
#
# **Desafío 1:** Crea una lista con los primeros 20 números de la serie de Fibonacci usando solo operaciones de listas (sin loops por ahora).
#
# **Desafío 2:** Dada una lista de números `[3, 1, 4, 1, 5, 9, 2, 6, 5, 3, 5]`, elimina todos los duplicados usando solo métodos de lista y muestra cuántos elementos únicos hay.
#
# **Desafío 3:** Invierte una lista sin usar `.reverse()` ni slicing `[::-1]`. ¿Puedes hacerlo con pop() y append()?
#
# ---
# ## 📝 Autoevaluación
#
# 1. ¿Cuál es el índice del último elemento en una lista de 5 elementos? →
# 2. ¿Diferencia entre `.sort()` y `sorted()`? →
# 3. ¿Qué retorna `.pop()`? →
# 4. ¿Cómo obtienes los últimos 3 elementos de una lista con slicing? →
# 5. ¿Pueden las listas contener diferentes tipos de datos? →

# %%
# Ejercicio 1.1
# Crea una lista con los nombres de 5 países de América Latina.
# Luego:
# a) Imprime el primer y el último país usando índices positivos y negativos
# b) Imprime los 3 países del centro
# c) Imprime el número total de países en la lista


paises = ["Mexico", "Guatemala", "Belice", "Chile", "Haiti"]


print(paises)
print(paises[0], paises[-1])
print(paises[1:4])


print (len(paises))
# Out:
# ['Mexico', 'Guatemala', 'Belice', 'Chile', 'Haiti']
# Mexico Haiti
# ['Guatemala', 'Belice', 'Chile']
# 5

# %%
# Ejercicio 1.2
# Dada esta lista de temperaturas semanales (lunes a domingo)
temperaturas = [18, 22, 19, 25, 28, 30, 27]
dias = ['Lunes', 'Martes', 'Miércoles', 'Jueves', 'Viernes', 'Sábado', 'Domingo']

# a) ¿Cuál fue la temperatura del miércoles?
print(f"La temperatura del miércoles fue: {temperaturas[2]}°C")

# b) ¿Cuáles fueron las temperaturas del fin de semana? (usando slicing)
# Asumiendo que el fin de semana es Sábado y Domingo (índices 5 y 6)
print(f"Las temperaturas del fin de semana fueron: {temperaturas[5:]}°C")

# c) ¿Cuál fue la temperatura más alta y en qué día ocurrió?
max_temp = max(temperaturas) # Encuentra la temperatura máxima
max_temp_index = temperaturas.index(max_temp) # Encuentra el índice de la temperatura máxima en la lista original
dia_max_temp = dias[max_temp_index] # Usa el índice para encontrar el día correspondiente
print(f"La temperatura más alta fue: {max_temp}°C y ocurrió el {dia_max_temp}")

# d) ¿Cuál fue el promedio de la semana? (redondea a 1 decimal)
import statistics # Importa el módulo statistics
promedio = round(statistics.mean(temperaturas), 1)
print(f"El promedio de la semana fue: {promedio}°C")
# Out:
# La temperatura del miércoles fue: 19°C
# Las temperaturas del fin de semana fueron: [30, 27]°C
# La temperatura más alta fue: 30°C y ocurrió el Sábado
# El promedio de la semana fue: 24.1°C

# %%
temperatura = 40
humedad     = 75
dia_laboral = True

# and — ambas condiciones deben ser True
if temperatura > 30 and humedad < 40:
    print("Clima perfecto para salir")
elif temperatura > 40 and humedad >= 80:
    print("Demasiado caliente")   # ← se ejecuta este
else:
    print("Mejor quedarse en casa")

# or — al menos una condición debe ser True
dia = "Lunes"
if dia == "Lunes" or dia == "Martes":
    print("¡Toca clase de pilates!")

# not — niega la condición
llueve = False
if not llueve:
    print("No está lloviendo — buen momento para salir")
# Out:
# Mejor quedarse en casa
# ¡Toca clase de pilates!
# No está lloviendo — buen momento para salir
